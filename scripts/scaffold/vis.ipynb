# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# plot contigs length distribution 
df = pd.read_csv('/work/hs325/diadema/results/ragtag/scaffolded/filtered_contig_lengths.txt', sep='\t')
df
# Out:
#                    #name    length
# 0      scaffold_1_RagTag  54224960
# 1     scaffold_10_RagTag  39989381
# 2     scaffold_11_RagTag  37622934
# 3     scaffold_12_RagTag  36070546
# 4     scaffold_13_RagTag  36040662
# ...                  ...       ...
# 3320          ptg002033l     12766
# 3321          ptg002034l     14115
# 3322          ptg002035l     12840
# 3323          ptg002040l     12670
# 3324          ptg002044l     12345
#
# [3325 rows x 2 columns]

# %%
scaffolds_sorted = scaffolds_df.sort_values(by='length_Mb', ascending=False).reset_index()

plt.figure(figsize=(12, 6))
plt.bar(scaffolds_sorted.index, scaffolds_sorted['length_Mb'], color='salmon', width=1.0)

plt.title('Scaffold Lengths', fontsize=14)
plt.xlabel('Scaffolds', fontsize=12)
plt.ylabel('Length (Mb)', fontsize=12)
plt.show()
